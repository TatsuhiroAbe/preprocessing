# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# # データを読み込む
# データはKaggleからダウンロードできます。
#
# [House Sales in King County, USA](https://www.kaggle.com/harlfoxem/housesalesprediction)

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df = df.loc[:, ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot']]
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot
# 0  221900.0         3       1.00         1180      5650
# 1  538000.0         3       2.25         2570      7242
# 2  180000.0         2       1.00          770     10000
# 3  604000.0         4       3.00         1960      5000
# 4  510000.0         3       2.00         1680      8080

# %% [markdown]
# # 欠損値の確認と処理
# 欠損値の確認には、isnullメソッドやinfoメソッドを使うと良いでしょう。
#
# infoメソッドを使うと、データ型も同時に確認できて便利です。

# %%
df.isnull().sum()
# Out:
# price          0
# bedrooms       0
# bathrooms      0
# sqft_living    0
# sqft_lot       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 5 columns):
# price          21613 non-null float64
# bedrooms       21613 non-null int64
# bathrooms      21613 non-null float64
# sqft_living    21613 non-null int64
# sqft_lot       21613 non-null int64
# dtypes: float64(2), int64(3)
# memory usage: 844.3 KB

# %% [markdown]
# このデータの場合、幸いにも欠損値はありませんでしたが、通常は多かれ少なかれ欠損値はあるものです。
#
# 欠損値のあるデータを削除したり、別の値で補完するときは以下のようなコードを書きます。

# %% [markdown]
# ## 削除する場合

# %%
# # 欠損値がある行をすべて削除
# df = df.dropna()

# # 欠損値の数を指定して削除（下の例の場合、同じ行に3つ以上欠損値があるとその行を削除）
# df.dropna(thresh=3)

# # 特定の列を基準に、その列が欠損していない部分だけを残す
# df = df[df['col'].isnull() == False]

# %% [markdown]
# ## 別の値で補完する場合

# %%
# # 定数で補完
# df['col'] = df['col'].fillna(5)

# # 平均値で補完
# df['col'] = df['col'].fillna(df['col'].mean())

# # 中央値で補完
# df['col'] = df['col'].fillna(df['col'].median())

# # 最頻値で補完
# df['col'] = df['col'].fillna(df['col'].mode()[0])

# %% [markdown]
# # 基本統計量の確認
# 基本統計量の計算には、describeメソッドを使うと便利です。
#
# この関数を呼びだせばだいたいの基本統計量が確認できますが、それぞれのデータごとの相関係数などは別に計算する必要があります。

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06

# %% [markdown]
# ## 相関係数の計算
# 相関係数の計算には、corrメソッドを使うと良いでしょう。

# %%
df.corr()
# Out:
#                 price  bedrooms  bathrooms  sqft_living  sqft_lot
# price        1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms     0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms    0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot     0.089661  0.031703   0.087740     0.172826  1.000000

# %% [markdown]
# # データごとの相関係数を可視化

# %%
sns.pairplot(df, plot_kws={'alpha': 0.2})

# %%
plt.figure(figsize=(10, 8)) 
sns.heatmap(df.corr(), annot=True, cmap='Blues')

# %% [markdown]
# # 箱ひげ図でデータの散らばり具合を確認

# %%
plt.figure(figsize=(10, 10))
sns.boxplot(df['price'], orient='v', width=0.5)

# %% [markdown]
# # 外れ値の処理
# 外れ値を処理するにはいくつかの方法がありますが、ここでは、四分位数と標準偏差をもとにした処理の方法を考えます。

# %% [markdown]
# ## 四分位数を使った方法（四分位範囲の1.5倍以上離れているものを除外）

# %%
def outlier_iqr(df, columns=None):
    if columns == None:
        columns = df.columns

    for col in columns:
        q1 = df[col].describe()['25%']
        q3 = df[col].describe()['75%']
        #四分位範囲
        iqr = q3 - q1 
        
        outlier_min = q1 - iqr * 1.5
        outlier_max = q3 + iqr * 1.5

        # 範囲から外れている値を除く
        df = df[(df[col] >= outlier_min) & (df[col] <= outlier_max)]
        
    return df

# %% [markdown]
# ## 標準偏差を使った方法（平均値から標準偏差のn倍離れているものを除外）

# %%
def outlier_std(df, thresh=3, columns=None):
    if columns == None:
        columns = df.columns

    for col in columns:
        mean = df[col].mean()
        std = df[col].std()
        
        # 平均値から標準偏差の何倍離れているかを計算
        border = (np.abs(df[col] - mean)) / std
        
        # 標準偏差の3倍以上離れているデータを除外
        df = df[(border < thresh)]
        
    return df

# %%
print("before", df.shape)
df = outlier_std(df, ['price'])
print("after", df.shape)
# Out:
# before (21613, 5)
# after (20547, 5)

# %% [markdown]
# # ヒストグラムによる可視化
# ヒストグラムによる可視化を行うには、seabornのdisplotメソッドを使うと、近似曲線も同時に描いていくれるので便利です。

# %%
plt.figure(figsize=(12, 8))
sns.distplot(df['price'])

# %% [markdown]
# # 対数変換
# 正規分布に従わないデータでも、対数変換を施すことで正規分布に近い形になるものがあります。
#
# 分析する手法によっては、データが正規分布に従っていることを前提としているものもあるので、対数変換の方法は覚えておくと良いでしょう。

# %%
df['price'] = np.log1p(df['price'])
df['price'].head()
# Out:
# 0    12.309987
# 1    13.195616
# 2    12.100718
# 3    13.311331
# 4    13.142168
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12, 8))
sns.distplot(df['price'])

# %% [markdown]
# # スケーリング
# スケーリングとは、文字通りデータの規模（スケール）を均一にする行為です。
#
# 代表的な方法は、平均0・分散1に変換する標準化や、最小値０・最大値１に変換する正規化です。
#
# いずれもsklearnを使うと簡単に処理が行えます。

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
for col in df.columns:
    scaler =  StandardScaler()
    df[col] = scaler.fit_transform(np.array(df[col].values).reshape(-1, 1))
    
df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
#       price  bedrooms  bathrooms  sqft_living  sqft_lot
# 0 -1.453661 -0.382456  -1.510184    -1.050276 -0.374743
# 1  0.402362 -0.382456   0.277368     0.765105 -0.252786
# 2 -1.892228 -1.545961  -1.510184    -1.585749 -0.041508
# 3  0.644868  0.781050   1.349899    -0.031573 -0.424536
# 4  0.290351 -0.382456  -0.080143    -0.397262 -0.188591
